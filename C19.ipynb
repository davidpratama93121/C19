# %% [markdown]
# # Analisis persebaran Covid-19
#
# Berikut adalah analisa persebaran covid-19 di dunia.

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib as plt

# %%
# %matplotlib inline

# %%
df = pd.read_excel('Negara yg terdampak.xlsx')

# %%
df
# Out:
#      sl_no           country  total_cases  new_cases  total_deaths  \
# 0      215             China        82941      8.000        4633.0
# 1       11             India        85940    156.000        2753.0
# 2        1               USA      1484285        NaN       88507.0
# 3       33         Indonesia        16496        NaN        1076.0
# 4       19          Pakistan        38799      1.581         834.0
# ..     ...               ...          ...        ...           ...
# 210    202        Montserrat           11        NaN           1.0
# 211    198  Falkland Islands           13        NaN           NaN
# 212    200      Vatican City           12        NaN           NaN
# 213    206        MS Zaandam            9        NaN           2.0
# 214    114  Diamond Princess          712        NaN          13.0
#
#      new_deaths  total_recovered  active_cases  serious_critical_cases  \
# 0           NaN          78219.0            89                    11.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   sl_no                    215 non-null    int64
#  1   country                  215 non-null    object
#  2   total_cases              215 non-null    int64
#  3   new_cases                22 non-null     float64
#  4   total_deaths             178 non-null    float64
#  5   new_deaths               12 non-null     float64
#  6   total_recovered          212 non-null    float64
#  7   active_cases             215 non-null    int64
#  8   serious_critical_cases   129 non-null    float64
#  9   total_cases_per_1m_pop   213 non-null    float64
#  10  total_deaths_per_1m_pop  176 non-null    float64
#  11  total_tests              185 non-null    float64
#  12  total_tests_per_1m_pop   185 non-null    float64
#  13  population               213 non-null    float64
# ...

# %%
df['country'].tail()
# Out:
# 210          Montserrat
# 211    Falkland Islands
# 212        Vatican City
# 213          MS Zaandam
# 214    Diamond Princess
# Name: country, dtype: object

# %% [markdown]
# Terdapat 214 Negara yang terdampak Covid 19.

# %%
df[df['total_cases']==df['total_cases'].max()]
# Out:
#    sl_no country  total_cases  new_cases  total_deaths  new_deaths  \
# 2      1     USA      1484285        NaN       88507.0         NaN
#
#    total_recovered  active_cases  serious_critical_cases  \
# 2         327751.0       1068027                 16139.0
#
#    total_cases_per_1m_pop  total_deaths_per_1m_pop  total_tests  \
# 2                  4488.0                    268.0   11090900.0
#
#    total_tests_per_1m_pop   population      rate
# 2                 33532.0  330758784.0  0.004488

# %% [markdown]
# Negara Amerika Serikat adalah negara yang paling terdampak virus corona dengan total 1484285 kasus.

# %%
df[df['total_cases']==df['total_cases'].min()]
# Out:
#      sl_no                country  total_cases  new_cases  total_deaths  \
# 143    213                Lesotho            1        NaN           NaN
# 209    214  Saint Pierre Miquelon            1        NaN           NaN
#
#      new_deaths  total_recovered  active_cases  serious_critical_cases  \
# 143         NaN              NaN             1                     NaN
# 209         NaN              1.0             0                     NaN
#
#      total_cases_per_1m_pop  total_deaths_per_1m_pop  total_tests  \
# 143                     5.0                      NaN          NaN
# 209                   173.0                      NaN          NaN
#
#      total_tests_per_1m_pop  population          rate
# 143                     NaN   2140096.0  4.672688e-07
# 209                     NaN      5797.0  1.725030e-04

# %% [markdown]
# Negara dengan kasus paling sedikit adalah Lesotho dan Saint Pierre Miquelon.

# %%
df[df['total_deaths']==df['total_deaths'].max()]
# Out:
#    sl_no country  total_cases  new_cases  total_deaths  new_deaths  \
# 2      1     USA      1484285        NaN       88507.0         NaN
#
#    total_recovered  active_cases  serious_critical_cases  \
# 2         327751.0       1068027                 16139.0
#
#    total_cases_per_1m_pop  total_deaths_per_1m_pop  total_tests  \
# 2                  4488.0                    268.0   11090900.0
#
#    total_tests_per_1m_pop   population      rate
# 2                 33532.0  330758784.0  0.004488

# %% [markdown]
# Manusia Amerika meninggal paling banyak selama ini dengan total kematian 88507 kasus

# %%
df[df['total_deaths']==df['total_deaths'].min()]
# Out:
#      sl_no                 country  total_cases  new_cases  total_deaths  \
# 76     196                 Burundi           15        NaN           1.0
# 140    184                  Gambia           23        NaN           1.0
# 141    182                Botswana           24        NaN           1.0
# 159    201                 Comoros           11        NaN           1.0
# 166    205                Suriname           10        NaN           1.0
# 170    155                  Brunei          141        NaN           1.0
# 176    150           French Guiana          189        NaN           1.0
# 184    193                Cura̤ao           16        NaN           1.0
# 193    166          Cayman Islands           94        NaN           1.0
# 200    199        Turks and Caicos           12        NaN           1.0
# 202    168           Liechtenstein           82        NaN           1.0
# 205    207  British Virgin Islands            8        NaN           1.0
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.corr()
# Out:
#                             sl_no  total_cases  new_cases  total_deaths  \
# sl_no                    1.000000    -0.298135  -0.277400     -0.311041
# total_cases             -0.298135     1.000000  -0.167685      0.937897
# new_cases               -0.277400    -0.167685   1.000000     -0.259507
# total_deaths            -0.311041     0.937897  -0.259507      1.000000
# new_deaths              -0.690149     0.532271  -0.511194      0.633216
# total_recovered         -0.360535     0.877125  -0.237598      0.840436
# active_cases            -0.227891     0.968185  -0.073011      0.855034
# serious_critical_cases  -0.285263     0.929331  -0.244230      0.850845
# total_cases_per_1m_pop  -0.204843     0.178755   0.237028      0.230113
# total_deaths_per_1m_pop -0.203560     0.246928   0.015498      0.390796
# total_tests             -0.384316     0.918477   0.131472      0.830571
# total_tests_per_1m_pop  -0.148734     0.066162  -0.020888      0.089442
# ...

# %%
sns.distplot(df['total_cases'])

# %%
sns.jointplot(x='population',y='total_cases',data=df,kind='scatter')

# %%
sns.jointplot(x='population',y='total_cases',data=df,kind='hex')

# %%
sns.pairplot(df)

# %% [markdown]
# # Maaf baru segini...
